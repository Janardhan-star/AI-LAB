# %%
# Simple Chatbot

print("Welcome to the Chatbot!")
print("Type 'exit' to stop the chatbot.\n")

while True:
    user = input("You: ").lower()

    if user == "hello":
        print("Bot: Hello! Welcome.")

    elif user == "name":
        print("Bot: My name is ChatBot.")

    elif user == "python":
        print("Bot: Python is a high-level, easy-to-learn programming language.")

    elif user == "marwadiuniversity":
        print("Bot: Marwadi University is located in Rajkot, Gujarat.")

    elif user == "exit":
        print("Bot: Thank you! Goodbye.")
        break

    else:
        print("Bot: Null")
# Out:
# Welcome to the Chatbot!
# Type 'exit' to stop the chatbot.
#
# You: hi
# Bot: Null
# You: hello
# Bot: Hello! Welcome.
# You: marrwadiuniversity
# Bot: Null
# You: marwadiuniversity
# Bot: Marwadi University is located in Rajkot, Gujarat.
# You: exit
# Bot: Thank you! Goodbye.

# %%
rint("Hello! I am cleaning robot.")
print("Today we will build a cleaning robot together:")
print(2 + 3, "is the answer to 2 + 3")

room = ["D", "C", "D", "D", "C"]

def show_room(room):
    picture = ""
    for spot in room:
        if spot == "D":
            picture += "💩 "
        else:
            picture += "✨ "
    print(picture)

print("Our room right now:")
show_room(room)

def clean_spot(spot):
    if spot == "D":
        return "C"
    else:
        return "C"

result = clean_spot("D")
print("The robot looked at a dirty spot 💩 and made it:", result,
      "(C means clean ✨)")

print("BEFORE - the dirty room:")
show_room(room)

for i in range(len(room)):
    room[i] = clean_spot(room[i])
    print("After cleaning spot number", i + 1, ":")
    show_room(room)

print()
print("AFTER - all done! ⭐⭐⭐⭐⭐⭐")

#####spam email detection


# List of spam keywords
spam_words = [
    "lottery",
    "winner",
    "prize",
    "free",
    "offer",
    "money",
    "click",
    "claim"
]

# Get email from user
email = input("Enter your email message:\n")

# Convert email to lowercase
email = email.lower()

# Check for spam words
spam = False

for word in spam_words:
    if word in email:
        spam = True
        break

# Display result
if spam:
    print("\nResult: Spam Mail")
else:
    print("\nResult: Not Spam Mail")
